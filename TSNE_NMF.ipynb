# %%
import numpy as np
import pandas as pd
import nltk
import re
import spacy
import gensim

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('resume.csv')
df = df.dropna(subset=['Resume_str'])

# %%
data = df.Resume_str.values.tolist()
data = [re.sub(r'\s+', ' ', sent) for sent in data]
data = [re.sub(r"\'", "", sent) for sent in data]
data = [re.sub('\w*\d\w*', ' ', sent) for sent in data]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
data_words = list(sent_to_words(data))

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'VERB'])

# %%
vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 0.5, 
                                min_df = 10)
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %%
no_topics = 20
nmf_model = NMF(n_components=no_topics).fit(data_vectorized)

# %%
topics_dict = {}
for topic_idx, topic in enumerate(nmf_model.components_):
    topics_dict["Topic"+str(topic_idx)] = [vectorizer.get_feature_names()[i] for i in topic.argsort()[:-10 - 1:-1]]

# %%
topics_to_df = pd.DataFrame(topics_dict).T
topics_to_df
# Out:
#                     0             1            2            3               4  \
# Topic0      equipment   maintenance       repair       safety         perform
# Topic1           food       kitchen         chef         menu            cost
# Topic2     accounting       account      prepare          tax  reconciliation
# Topic3      marketing        market     strategy        brand        campaign
# Topic4        student       teacher       school          art       classroom
# Topic5        quality    production  engineering      control       inventory
# Topic6   construction          site     schedule     building          budget
# Topic7       employee      resource      benefit       policy            hire
# Topic8         design      designer          art  engineering         concept
# Topic9       analysis       finance       budget      analyze           datum
# Topic10       network        server     software     security      technology
# Topic11         store          cash  merchandise    inventory           order
# Topic12         datum   application     database       oracle            user
# Topic13           bar         guest     beverage        serve            food
# Topic14       account  relationship       credit       review           issue
# Topic15        medium      relation        event        press           write
# Topic16       patient          care       health      nursing           nurse
# Topic17          test       testing     software      quality     requirement
# Topic18    technology    leadership  performance       result        strategy
# Topic19       fitness        health     exercise        group        wellness
#
#                    5              6               7            8             9
# Topic0     personnel       aviation        aircraft     material       control
# Topic1   preparation           item      restaurant      quality          cook
# Topic2     statement        payroll            cash         bank    accountant
# Topic3   advertising       increase         content       budget       website
# Topic4        lesson         parent           child        grade         teach
# Topic5          cost  manufacturing     improvement     engineer      material
# Topic6        safety     contractor        material   completion         build
# Topic7       payroll        conduct       interview  recruitment   performance
# Topic8      engineer       material        software      drawing    production
# Topic9     reporting       forecast            risk     planning          cost
# Topic10     hardware         window        computer         user  troubleshoot
# Topic11    associate        receive            make         help          area
# Topic12       server            web        solution          sql   requirement
# Topic13        drink        prepare            area        table         order
# Topic14      payment           loan         resolve    insurance      research
# Topic15      content       campaign         release     strategy     community
# Topic16       record      treatment          family    procedure          home
# Topic17     engineer        perform            case  engineering        flight
# Topic18     solution       increase  implementation     director       revenue
# Topic19        coach          class         trainer      certify         event

# %%
topics = ['Warehouse','Chef','Accounting',
          'Marketing','Teacher','Engineering',
          'Construction','HR','Engineering','Finance',
          'Healthcare','Sales','Database','Bartender','ProductControl',
          'Politics','Fitness','Aviation',
          'IT','Arts']

topics_to_df["Topics"] = topics
topics_to_df
# Out:
#                     0             1            2            3               4  \
# Topic0      equipment   maintenance       repair       safety         perform
# Topic1           food       kitchen         chef         menu            cost
# Topic2     accounting       account      prepare          tax  reconciliation
# Topic3      marketing        market     strategy        brand        campaign
# Topic4        student       teacher       school          art       classroom
# Topic5        quality    production  engineering      control       inventory
# Topic6   construction          site     schedule     building          budget
# Topic7       employee      resource      benefit       policy            hire
# Topic8         design      designer          art  engineering         concept
# Topic9       analysis       finance       budget      analyze           datum
# Topic10       network        server     software     security      technology
# Topic11         store          cash  merchandise    inventory           order
# Topic12         datum   application     database       oracle            user
# Topic13           bar         guest     beverage        serve            food
# Topic14       account  relationship       credit       review           issue
# Topic15        medium      relation        event        press           write
# Topic16       patient          care       health      nursing           nurse
# Topic17          test       testing     software      quality     requirement
# Topic18    technology    leadership  performance       result        strategy
# Topic19       fitness        health     exercise        group        wellness
#
#                    5              6               7            8  \
# Topic0     personnel       aviation        aircraft     material
# Topic1   preparation           item      restaurant      quality
# Topic2     statement        payroll            cash         bank
# Topic3   advertising       increase         content       budget
# Topic4        lesson         parent           child        grade
# Topic5          cost  manufacturing     improvement     engineer
# Topic6        safety     contractor        material   completion
# Topic7       payroll        conduct       interview  recruitment
# Topic8      engineer       material        software      drawing
# Topic9     reporting       forecast            risk     planning
# Topic10     hardware         window        computer         user
# Topic11    associate        receive            make         help
# Topic12       server            web        solution          sql
# Topic13        drink        prepare            area        table
# Topic14      payment           loan         resolve    insurance
# Topic15      content       campaign         release     strategy
# Topic16       record      treatment          family    procedure
# Topic17     engineer        perform            case  engineering
# Topic18     solution       increase  implementation     director
# Topic19        coach          class         trainer      certify
#
#                     9          Topics
# Topic0        control       Warehouse
# Topic1           cook            Chef
# Topic2     accountant      Accounting
# Topic3        website       Marketing
# Topic4          teach         Teacher
# Topic5       material     Engineering
# Topic6          build    Construction
# Topic7    performance              HR
# Topic8     production     Engineering
# Topic9           cost         Finance
# Topic10  troubleshoot      Healthcare
# Topic11          area           Sales
# Topic12   requirement        Database
# Topic13         order       Bartender
# Topic14      research  ProductControl
# Topic15     community        Politics
# Topic16          home         Fitness
# Topic17        flight        Aviation
# Topic18       revenue              IT
# Topic19         event            Arts

# %%
topics_matrix = nmf_model.transform(data_vectorized)
topics_matrix_std = StandardScaler().fit_transform(topics_matrix)

# %%
threshold = 0.02
_idx = np.amax(topics_matrix, axis=1) > threshold
topics_matrix_filtered = topics_matrix[_idx]

topics_matrix_std = StandardScaler().fit_transform(topics_matrix_filtered)

# %%
tsne = TSNE(n_components=2, verbose=1, random_state=20, init='pca')
topics_mapped_2d = tsne.fit_transform(topics_matrix_std)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2483 samples in 0.009s...
# [t-SNE] Computed neighbors for 2483 samples in 0.181s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2483
# [t-SNE] Computed conditional probabilities for sample 2000 / 2483
# [t-SNE] Computed conditional probabilities for sample 2483 / 2483
# [t-SNE] Mean sigma: 0.826902
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.410339
# [t-SNE] KL divergence after 1000 iterations: 1.065550

# %%
max_topic_per_post = []
for i in range(topics_matrix_filtered.shape[0]):
    max_topic_per_post += topics_matrix_filtered[i].argmax(),

max_topic_per_post_df = []
for i in range(topics_matrix.shape[0]):
    max_topic_per_post_df += topics_matrix[i].argmax(),
    
max_topic_per_post = [[x] for x in max_topic_per_post]
tsne_data = np.concatenate((topics_mapped_2d, max_topic_per_post), 1)

# %%
label_list = list(range(20))

plt.figure(figsize=(15, 10))
for idx in range(len(topics_to_df.Topics)):
    inds = np.where(tsne_data[:, 2] == idx)[0]
    plt.scatter(x=tsne_data[inds, 0],
                y=tsne_data[inds, 1],
                marker='o',
                label=topics_to_df.Topics[idx])

plt.xlabel('t-SNE Component 1', fontsize=12)
plt.ylabel('t-SNE Component 2', fontsize=12)
plt.title('T-SNE Cluster with NMF Model')
lgnd = plt.legend(loc="lower right", fontsize=12)

# %%
df['topic'] = max_topic_per_post_df

# %%
topic_bar = df.topic.value_counts().reset_index().rename(columns={'index':'Topic', 'topic':'Count'}).sort_values('Count', ascending=False)

# %%
topic_bar.Topic=topic_bar.Topic.apply(lambda x: topics[x])

# %%
plt.figure(figsize=(16,12))
barchart = sns.barplot(data=topic_bar, x='Count', y='Topic', ci=None)
barchart.set_xlabel('Count')
barchart.set_ylabel('Topic')
barchart.set_title("Topic Model with NMF")
# Out:
# Text(0.5, 1.0, 'Topic Model with NMF')
